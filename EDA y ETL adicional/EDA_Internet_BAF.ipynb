# %% [markdown]
# # EDA y ETL Internet BAF

# %% [markdown]
# ### Data resumida

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Internet_BAF = pd.read_csv('../Datasets/Internet_BAF.csv')

# %%
Internet_BAF.head(36)
# Out:
#      Año  Trimestre  Banda ancha fija  Dial up  Total        Periodo
# 0   2022          4                11       12     11   Oct-Dic 2022
# 1   2022          3                11       12     11  Jul-Sept 2022
# 2   2022          2                11       12     11   Abr-Jun 2022
# 3   2022          1                11       13     11   Ene-Mar 2022
# 4   2021          4                10       13     10   Oct-Dic 2021
# 5   2021          3                10       10     10  Jul-Sept 2021
# 6   2021          2                10       10     10   Abr-Jun 2021
# 7   2021          1                10       10     10   Ene-Mar 2021
# 8   2020          4                10       10     10   Oct-Dic 2020
# 9   2020          3                 9       10      9  Jul-Sept 2020
# 10  2020          2                 9       10      9   Abr-Jun 2020
# 11  2020          1                 9       10      9   Ene-Mar 2020
# 12  2019          4                 9       10      9   Oct-Dic 2019
# ...

# %%
Internet_BAF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Año               36 non-null     int64
#  1   Trimestre         36 non-null     int64
#  2   Banda ancha fija  36 non-null     int64
#  3   Dial up           36 non-null     int64
#  4   Total             36 non-null     int64
#  5   Periodo           36 non-null     object
# dtypes: int64(5), object(1)
# memory usage: 1.8+ KB

# %% [markdown]
# Sabemos que en la argentina uno de las opciones mas antiguas y menos usadas en todos estos ultimos años es el dial up, y por lo que podemos ver en este Dataframe que contiene datos con errores nos muestra que los accesos del dial up es superior a la de banda ancha lo cual es imposible asi que no tendremos en cuenta esta informacion para las decisiones que tomaremos proximamente

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Internet BAF (completo)

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %%
Internet_BAF_1 = pd.read_csv('../Datasets/Internet_BAF (1).csv')

# %%
Internet_BAF_1.head()
# Out:
#     Año  Trimestre        Provincia  Banda ancha fija  Dial up  Total
# 0  2022          4     Buenos Aires                 5      6.0      5
# 1  2022          4  Capital Federal                 2      2.0      2
# 2  2022          4        Catamarca                71      1.0     71
# 3  2022          4            Chaco               144      5.0    144
# 4  2022          4           Chubut               168    904.0    169

# %%
Internet_BAF_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Año               864 non-null    int64
#  1   Trimestre         864 non-null    int64
#  2   Provincia         864 non-null    object
#  3   Banda ancha fija  864 non-null    int64
#  4   Dial up           862 non-null    float64
#  5   Total             864 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 40.6+ KB

# %%
Internet_BAF_1 = Internet_BAF_1.drop_duplicates()

# %% [markdown]
# # GRAFICOS

# %% [markdown]
# Haremos los graficos con los datos de Banda ancha fija y dejaremos de lado el dial up ya que ese sistema no es tan usado y casi que ni modifica los totales de estos dos valores sumados.

# %%
plt.figure(figsize=(12, 8))

# Crea un gráfico de líneas para todas las provincias
sns.lineplot(data=Internet_BAF_1, x='Año', y='Banda ancha fija', hue='Provincia', err_style=None)

plt.title("Tendencia de Banda ancha fija (Todas las Provincias)")
plt.xlabel("Año")
plt.ylabel("Banda ancha fija")

# Ajusta la leyenda para que no se superponga
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
plt.figure(figsize=(10, 6))

# Crea un gráfico de cajas
sns.boxplot(data=Internet_BAF_1, x='Año', y='Banda ancha fija',hue= 'Año', palette='coolwarm')

plt.title("Distribución de Banda ancha fija")
plt.xlabel("Año")
plt.ylabel("Banda ancha fija")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(14, 8))

# Crea un gráfico de cajas
sns.boxplot(data=Internet_BAF_1, x='Provincia', y='Banda ancha fija',hue= 'Provincia', palette='coolwarm')

plt.title("Distribución de Banda ancha fija")
plt.xlabel("Provincia")
plt.ylabel("Banda ancha fija")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Luego de estos tres graficos con los datos cargados incorrectamente se nos hace imposible llegar a hacer una evaluacion de estos datos, ya que no vemos con claridad lo que puede llegar a suceder asi que procederemos a no tener en cuenta esta informacion para las conclusiones finales
