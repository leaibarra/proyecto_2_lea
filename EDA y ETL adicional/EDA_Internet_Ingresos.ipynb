# %% [markdown]
# # Internet Ingresos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ingresos = pd.read_csv('../Datasets/Internet_Ingresos.csv')

# %%
ingresos.head()
# Out:
#     Año  Trimestre  Ingresos (miles de pesos)
# 0  2022          4                         72
# 1  2022          3                         64
# 2  2022          2                         60
# 3  2022          1                         55
# 4  2021          4                         45

# %%
ingresos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Año                        36 non-null     int64
#  1   Trimestre                  36 non-null     int64
#  2   Ingresos (miles de pesos)  36 non-null     int64
#  3   Periodo                    36 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# Eliminamos la columna 'Periodo' ya que proporciona la misma información que la columna 'Trimestre'. Asi no tenemos informacion duplicada procedemos a eliminarla

# %%
ingresos = ingresos.drop(columns= ['Periodo'])

# %%
plt.figure(figsize=(16, 10))

# Creamos el gráfico de líneas por año y tipo de conexión
sns.lineplot(data=ingresos, x='Año', y='Ingresos (miles de pesos)')

# Agregamos título y etiquetas
plt.title('Ingresos (en miles de $) por año')
plt.xlabel('Año')
plt.ylabel('$$$$$$$$$')

# Mostramos el gráfico
plt.show()

# %% [markdown]
# Efectivamente vemos que los ingrsos suben gradualmente al pasar los años
